# %% [markdown]
# # Esse Tutorial mostra como criar um classificador de imagens usando redes neurais convolucionais capaz de diferenciar classes de imagens utilizando tf.keras no Google Colab.
#
# # Aqui, vamos cobrir:
# - importação de dados
# - pré-processamento
# - criação do modelo
# - treinamento
# - avaliação
# - predições
#
# # Antes de começar, alterar o ambiente de execução para GPU

# %% [markdown]
# ## 1. Importação das bibliotecas necessárias

# %%
import os
from zipfile import ZipFile
import shutil
import gdown

from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ## 2. Download e descompactação da base de dados

# %%
# !gdown 1jLm7U5Nin_7LQVW1F-sGvHdcJ52t5_6V
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1jLm7U5Nin_7LQVW1F-sGvHdcJ52t5_6V
# To: /content/imagens-tratadas-data.zip
# 100% 6.73M/6.73M [00:00<00:00, 88.6MB/s]

# %%
file_name = "imagens-tratadas-data.zip"

with ZipFile(file_name, 'r') as zip:
    dataset_home = './'
    os.makedirs(dataset_home, exist_ok=True)

    zip.printdir()

    print('Extracting all the files now...')
    zip.extractall()
    print('Done!')
# Out:
# File Name                                             Modified             Size
# imagens-tratadas-data/train_set/               2024-02-28 10:11:30            0
# imagens-tratadas-data/train_set/anormais-segmentadas/ 2024-02-28 10:12:56            0
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb001_mod.png 2024-02-28 00:08:00        27046
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb002_mod.png 2024-02-28 00:08:00        18312
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb005_mod.png 2024-02-28 00:08:00        23447
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb005'_mod.png 2024-02-28 00:08:00        24041
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb010_mod.png 2024-02-28 00:08:00        24806
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb012_mod.png 2024-02-28 00:08:00        29314
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb013_mod.png 2024-02-28 00:08:00        22169
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb015_mod.png 2024-02-28 00:08:00        27884
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb017_mod.png 2024-02-28 00:08:00        25330
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb019_mod.png 2024-02-28 00:08:00        26823
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb021_mod.png 2024-02-28 00:08:00        26035
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb023_mod.png 2024-02-28 00:08:00        26714
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb025_mod.png 2024-02-28 00:08:00        28658
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb028_mod.png 2024-02-28 00:08:00        28268
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb030_mod.png 2024-02-28 00:08:00        26477
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb032_mod.png 2024-02-28 00:08:00        28372
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb058_mod.png 2024-02-28 00:08:00        28749
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb059_mod.png 2024-02-28 00:08:00        13347
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb063_mod.png 2024-02-28 00:08:00        27353
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb069_mod.png 2024-02-28 00:08:00        28691
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb072_mod.png 2024-02-28 00:08:00        26395
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb075_mod.png 2024-02-28 00:08:00        28616
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb080_mod.png 2024-02-28 00:08:00        19747
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb081_mod.png 2024-02-28 00:08:00        26460
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb083_mod.png 2024-02-28 00:08:00        22263
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb090_mod.png 2024-02-28 00:08:00        23957
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb091_mod.png 2024-02-28 00:08:00        13627
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb092_mod.png 2024-02-28 00:08:00        29109
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb095_mod.png 2024-02-28 00:08:00        28297
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb097_mod.png 2024-02-28 00:08:00        27087
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb099_mod.png 2024-02-28 00:08:00        10338
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb102_mod.png 2024-02-28 00:08:00        27669
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb104_mod.png 2024-02-28 00:08:00        28152
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb105_mod.png 2024-02-28 00:08:00        21210
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb107_mod.png 2024-02-28 00:08:00        25830
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb110_mod.png 2024-02-28 00:08:00        21966
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb111_mod.png 2024-02-28 00:08:00        26503
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb115_mod.png 2024-02-28 00:08:00        26160
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb117_mod.png 2024-02-28 00:08:00        28983
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb120_mod.png 2024-02-28 00:08:00        27817
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb121_mod.png 2024-02-28 00:08:00        28275
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb124_mod.png 2024-02-28 00:08:00        29889
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb125_mod.png 2024-02-28 00:08:00        23863
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb126_mod.png 2024-02-28 00:08:00        27132
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb127_mod.png 2024-02-28 00:08:00        28464
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb130_mod.png 2024-02-28 00:08:00        27454
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb132_mod.png 2024-02-28 00:08:00        27630
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb132'_mod.png 2024-02-28 00:08:00        27013
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb134_mod.png 2024-02-28 00:08:00        27745
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb141_mod.png 2024-02-28 00:08:00        27248
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb142_mod.png 2024-02-28 00:08:00        26874
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb144_mod.png 2024-02-28 00:08:00        26565
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb144'_mod.png 2024-02-28 00:08:00        26956
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb145_mod.png 2024-02-28 00:08:00        29496
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb148_mod.png 2024-02-28 00:08:00        28871
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb150_mod.png 2024-02-28 00:08:00        28853
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb152_mod.png 2024-02-28 00:08:00        23947
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb155_mod.png 2024-02-28 00:08:00        28655
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb158_mod.png 2024-02-28 00:08:00        28500
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb160_mod.png 2024-02-28 00:08:00        29563
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb163_mod.png 2024-02-28 00:08:00        27225
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb165_mod.png 2024-02-28 00:08:00        25167
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb167_mod.png 2024-02-28 00:08:00        28734
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb170_mod.png 2024-02-28 00:08:00        29949
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb171_mod.png 2024-02-28 00:08:00        24016
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb175_mod.png 2024-02-28 00:08:00        25736
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb178_mod.png 2024-02-28 00:08:00        28277
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb179_mod.png 2024-02-28 00:08:00        20307
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb181_mod.png 2024-02-28 00:08:00        27475
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb184_mod.png 2024-02-28 00:08:00        26037
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb186_mod.png 2024-02-28 00:08:00        31328
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb188_mod.png 2024-02-28 00:08:00        28584
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb190_mod.png 2024-02-28 00:08:00        27453
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb191_mod.png 2024-02-28 00:08:00        17287
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb193_mod.png 2024-02-28 00:08:00        28690
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb195_mod.png 2024-02-28 00:08:00        16734
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb198_mod.png 2024-02-28 00:08:00        28577
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb199_mod.png 2024-02-28 00:08:00        18339
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb202_mod.png 2024-02-28 00:08:00        26694
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb204_mod.png 2024-02-28 00:08:00        26978
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb206_mod.png 2024-02-28 00:08:00        16253
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb207_mod.png 2024-02-28 00:08:00        24843
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb209_mod.png 2024-02-28 00:08:00        30260
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb211_mod.png 2024-02-28 00:08:00        13248
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb213_mod.png 2024-02-28 00:08:00        25410
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb216_mod.png 2024-02-28 00:08:00        20590
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb218_mod.png 2024-02-28 00:08:00        27019
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb219_mod.png 2024-02-28 00:08:00        27637
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb222_mod.png 2024-02-28 00:08:00        27897
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb223_mod.png 2024-02-28 00:08:00        26001
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb223'_mod.png 2024-02-28 00:08:00        15741
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb226_mod.png 2024-02-28 00:08:00        27975
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb226'_mod.png 2024-02-28 00:08:00        28377
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb226''_mod.png 2024-02-28 00:08:00        23144
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb227_mod.png 2024-02-28 00:08:00        29528
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb231_mod.png 2024-02-28 00:08:00        29396
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb233_mod.png 2024-02-28 00:08:00        15568
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb236_mod.png 2024-02-28 00:08:00        25094
# imagens-tratadas-data/train_set/anormais-segmentadas/mdb238_mod.png 2024-02-28 00:08:00        26612
# imagens-tratadas-data/train_set/normais-redimensionadas/ 2024-02-28 10:16:12            0
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb003_mod.png 2024-02-28 00:08:00        18563
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb004_mod.png 2024-02-28 00:08:00        19604
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb006_mod.png 2024-02-28 00:08:00        19549
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb007_mod.png 2024-02-28 00:08:00        17826
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb008_mod.png 2024-02-28 00:08:00        20426
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb009_mod.png 2024-02-28 00:08:00        19931
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb011_mod.png 2024-02-28 00:08:00        18428
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb014_mod.png 2024-02-28 00:08:00        17210
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb016_mod.png 2024-02-28 00:08:00        15278
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb018_mod.png 2024-02-28 00:08:00        12978
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb020_mod.png 2024-02-28 00:08:00        20909
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb022_mod.png 2024-02-28 00:08:00        16294
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb024_mod.png 2024-02-28 00:08:00        18980
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb026_mod.png 2024-02-28 00:08:00        19012
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb027_mod.png 2024-02-28 00:08:00        19277
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb029_mod.png 2024-02-28 00:08:00        19243
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb031_mod.png 2024-02-28 00:08:00        20781
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb033_mod.png 2024-02-28 00:08:00        12683
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb034_mod.png 2024-02-28 00:08:00        13169
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb035_mod.png 2024-02-28 00:08:00        12647
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb036_mod.png 2024-02-28 00:08:00        13294
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb037_mod.png 2024-02-28 00:08:00        12752
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb038_mod.png 2024-02-28 00:08:00        11515
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb039_mod.png 2024-02-28 00:08:00        11341
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb040_mod.png 2024-02-28 00:08:00         8847
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb041_mod.png 2024-02-28 00:08:00        15903
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb042_mod.png 2024-02-28 00:08:00        16828
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb043_mod.png 2024-02-28 00:08:00        12832
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb044_mod.png 2024-02-28 00:08:00        13876
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb045_mod.png 2024-02-28 00:08:00        17072
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb046_mod.png 2024-02-28 00:08:00        17739
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb047_mod.png 2024-02-28 00:08:00        15753
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb048_mod.png 2024-02-28 00:08:00        16001
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb049_mod.png 2024-02-28 00:08:00        19787
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb050_mod.png 2024-02-28 00:09:00        19670
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb051_mod.png 2024-02-28 00:09:00        21185
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb052_mod.png 2024-02-28 00:09:00        15349
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb053_mod.png 2024-02-28 00:09:00        12285
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb054_mod.png 2024-02-28 00:09:00        11729
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb055_mod.png 2024-02-28 00:09:00        13821
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb056_mod.png 2024-02-28 00:09:00        11769
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb057_mod.png 2024-02-28 00:09:00        18566
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb060_mod.png 2024-02-28 00:09:00        12973
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb061_mod.png 2024-02-28 00:09:00        12518
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb062_mod.png 2024-02-28 00:09:00        12521
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb064_mod.png 2024-02-28 00:09:00        15298
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb065_mod.png 2024-02-28 00:09:00        14845
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb066_mod.png 2024-02-28 00:09:00        15594
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb067_mod.png 2024-02-28 00:09:00        22913
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb068_mod.png 2024-02-28 00:09:00        21929
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb070_mod.png 2024-02-28 00:09:00        19246
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb071_mod.png 2024-02-28 00:09:00        12602
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb073_mod.png 2024-02-28 00:09:00        11316
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb074_mod.png 2024-02-28 00:09:00        10733
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb076_mod.png 2024-02-28 00:09:00        16364
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb077_mod.png 2024-02-28 00:09:00        18852
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb078_mod.png 2024-02-28 00:09:00        17512
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb079_mod.png 2024-02-28 00:09:00        15617
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb082_mod.png 2024-02-28 00:09:00        20860
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb084_mod.png 2024-02-28 00:09:00        21190
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb085_mod.png 2024-02-28 00:09:00        14898
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb086_mod.png 2024-02-28 00:09:00        14415
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb087_mod.png 2024-02-28 00:09:00        14664
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb088_mod.png 2024-02-28 00:09:00        14199
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb089_mod.png 2024-02-28 00:09:00        13989
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb093_mod.png 2024-02-28 00:09:00        14158
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb094_mod.png 2024-02-28 00:09:00        15871
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb096_mod.png 2024-02-28 00:09:00        16235
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb098_mod.png 2024-02-28 00:09:00        18224
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb100_mod.png 2024-02-28 00:09:00        16039
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb101_mod.png 2024-02-28 00:09:00        16492
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb103_mod.png 2024-02-28 00:09:00        16024
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb106_mod.png 2024-02-28 00:09:00        21413
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb108_mod.png 2024-02-28 00:09:00        21246
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb109_mod.png 2024-02-28 00:09:00        18837
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb112_mod.png 2024-02-28 00:09:00        22648
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb113_mod.png 2024-02-28 00:09:00        13807
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb114_mod.png 2024-02-28 00:09:00        11568
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb116_mod.png 2024-02-28 00:09:00        21085
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb118_mod.png 2024-02-28 00:09:00        16893
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb119_mod.png 2024-02-28 00:09:00        19941
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb122_mod.png 2024-02-28 00:09:00        19484
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb123_mod.png 2024-02-28 00:09:00        17237
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb128_mod.png 2024-02-28 00:09:00        12173
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb129_mod.png 2024-02-28 00:09:00        20987
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb131_mod.png 2024-02-28 00:09:00        27012
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb133_mod.png 2024-02-28 00:09:00        30493
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb135_mod.png 2024-02-28 00:09:00        27002
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb136_mod.png 2024-02-28 00:09:00        24846
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb137_mod.png 2024-02-28 00:09:00        18593
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb138_mod.png 2024-02-28 00:09:00        18866
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb139_mod.png 2024-02-28 00:09:00        26088
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb140_mod.png 2024-02-28 00:09:00        26917
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb143_mod.png 2024-02-28 00:09:00        29217
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb146_mod.png 2024-02-28 00:09:00        26011
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb147_mod.png 2024-02-28 00:09:00        30758
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb149_mod.png 2024-02-28 00:09:00        26111
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb151_mod.png 2024-02-28 00:09:00        28522
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb153_mod.png 2024-02-28 00:09:00        25942
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb154_mod.png 2024-02-28 00:09:00        24882
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb156_mod.png 2024-02-28 00:09:00        20799
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb157_mod.png 2024-02-28 00:09:00        15968
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb159_mod.png 2024-02-28 00:09:00        20137
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb161_mod.png 2024-02-28 00:09:00        16178
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb162_mod.png 2024-02-28 00:09:00        14711
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb164_mod.png 2024-02-28 00:09:00        18602
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb166_mod.png 2024-02-28 00:09:00        10728
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb168_mod.png 2024-02-28 00:09:00        19224
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb169_mod.png 2024-02-28 00:09:00        15115
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb172_mod.png 2024-02-28 00:09:00        18025
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb173_mod.png 2024-02-28 00:09:00        20128
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb174_mod.png 2024-02-28 00:09:00        20407
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb176_mod.png 2024-02-28 00:09:00        13474
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb177_mod.png 2024-02-28 00:09:00        11127
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb180_mod.png 2024-02-28 00:09:00        11069
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb182_mod.png 2024-02-28 00:09:00        15488
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb183_mod.png 2024-02-28 00:09:00        20897
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb185_mod.png 2024-02-28 00:09:00        14681
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb187_mod.png 2024-02-28 00:09:00        16550
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb189_mod.png 2024-02-28 00:09:00        20749
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb192_mod.png 2024-02-28 00:09:00        13431
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb194_mod.png 2024-02-28 00:09:00        20829
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb196_mod.png 2024-02-28 00:09:00        21890
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb197_mod.png 2024-02-28 00:09:00        17625
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb200_mod.png 2024-02-28 00:09:00        16854
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb201_mod.png 2024-02-28 00:09:00        21956
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb203_mod.png 2024-02-28 00:09:00        19788
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb205_mod.png 2024-02-28 00:09:00        19066
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb208_mod.png 2024-02-28 00:09:00        15355
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb210_mod.png 2024-02-28 00:09:00        20996
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb212_mod.png 2024-02-28 00:09:00        16271
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb214_mod.png 2024-02-28 00:09:00        13226
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb215_mod.png 2024-02-28 00:09:00        22754
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb217_mod.png 2024-02-28 00:09:00        19841
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb220_mod.png 2024-02-28 00:09:00        21566
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb221_mod.png 2024-02-28 00:09:00        16491
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb224_mod.png 2024-02-28 00:09:00        13543
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb225_mod.png 2024-02-28 00:09:00        15662
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb228_mod.png 2024-02-28 00:09:00        14020
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb229_mod.png 2024-02-28 00:09:00        17826
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb230_mod.png 2024-02-28 00:09:00        18159
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb232_mod.png 2024-02-28 00:09:00        21050
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb234_mod.png 2024-02-28 00:09:00        14545
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb235_mod.png 2024-02-28 00:09:00        20687
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb237_mod.png 2024-02-28 00:09:00        16521
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb242_mod.png 2024-02-28 00:09:00        13692
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb243_mod.png 2024-02-28 00:09:00        17299
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb246_mod.png 2024-02-28 00:09:00        13187
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb247_mod.png 2024-02-28 00:09:00        19420
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb250_mod.png 2024-02-28 00:09:00        16590
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb251_mod.png 2024-02-28 00:09:00        16841
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb254_mod.png 2024-02-28 00:09:00        21846
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb255_mod.png 2024-02-28 00:09:00        19560
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb257_mod.png 2024-02-28 00:09:00        17895
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb258_mod.png 2024-02-28 00:09:00        18967
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb259_mod.png 2024-02-28 00:09:00        20438
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb260_mod.png 2024-02-28 00:09:00        21536
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb261_mod.png 2024-02-28 00:09:00        12698
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb262_mod.png 2024-02-28 00:09:00        12770
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb263_mod.png 2024-02-28 00:09:00        16856
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb266_mod.png 2024-02-28 00:09:00        14358
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb268_mod.png 2024-02-28 00:09:00        18856
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb269_mod.png 2024-02-28 00:09:00        16042
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb272_mod.png 2024-02-28 00:09:00        19280
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb273_mod.png 2024-02-28 00:09:00        20732
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb275_mod.png 2024-02-28 00:09:00        17363
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb276_mod.png 2024-02-28 00:09:00        17638
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb277_mod.png 2024-02-28 00:09:00        16791
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb278_mod.png 2024-02-28 00:09:00        16172
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb279_mod.png 2024-02-28 00:09:00        21201
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb280_mod.png 2024-02-28 00:09:00        29442
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb281_mod.png 2024-02-28 00:09:00        15620
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb282_mod.png 2024-02-28 00:09:00        14938
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb283_mod.png 2024-02-28 00:09:00        17689
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb284_mod.png 2024-02-28 00:09:00        16049
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb285_mod.png 2024-02-28 00:09:00        17705
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb286_mod.png 2024-02-28 00:09:00        17242
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb287_mod.png 2024-02-28 00:09:00        12475
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb288_mod.png 2024-02-28 00:09:00        11916
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb289_mod.png 2024-02-28 00:09:00        13570
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb291_mod.png 2024-02-28 00:09:00        20221
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb292_mod.png 2024-02-28 00:09:00        20248
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb293_mod.png 2024-02-28 00:09:00        20536
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb294_mod.png 2024-02-28 00:09:00        19445
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb295_mod.png 2024-02-28 00:09:00        20742
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb296_mod.png 2024-02-28 00:09:00        20196
# imagens-tratadas-data/train_set/normais-redimensionadas/mdb297_mod.png 2024-02-28 00:09:00        17572
# imagens-tratadas-data/val_set/                 2024-02-28 10:12:02            0
# imagens-tratadas-data/val_set/anormais-segmentadas/ 2024-02-28 10:15:42            0
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb239_mod.png 2024-02-28 00:08:00        25710
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb239'_mod.png 2024-02-28 00:08:00        26689
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb240_mod.png 2024-02-28 00:08:00        21953
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb241_mod.png 2024-02-28 00:08:00        28158
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb244_mod.png 2024-02-28 00:08:00        27121
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb245_mod.png 2024-02-28 00:08:00        13995
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb248_mod.png 2024-02-28 00:08:00        29902
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb249_mod.png 2024-02-28 00:08:00        29523
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb249'_mod.png 2024-02-28 00:08:00        28903
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb252_mod.png 2024-02-28 00:08:00        26662
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb253_mod.png 2024-02-28 00:08:00        15011
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb256_mod.png 2024-02-28 00:08:00        27588
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb264_mod.png 2024-02-28 00:08:00        22335
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb265_mod.png 2024-02-28 00:08:00        26726
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb267_mod.png 2024-02-28 00:08:00        12041
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb270_mod.png 2024-02-28 00:08:00        28864
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb271_mod.png 2024-02-28 00:08:00        14638
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb274_mod.png 2024-02-28 00:08:00        28506
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb290_mod.png 2024-02-28 00:08:00        25576
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb312_mod.png 2024-02-28 00:08:00        23174
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb314_mod.png 2024-02-28 00:08:00        24755
# imagens-tratadas-data/val_set/anormais-segmentadas/mdb315_mod.png 2024-02-28 00:08:00        25569
# imagens-tratadas-data/val_set/normais-redimensionadas/ 2024-02-28 10:16:00            0
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb298_mod.png 2024-02-28 00:09:00        16962
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb299_mod.png 2024-02-28 00:09:00        19452
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb300_mod.png 2024-02-28 00:09:00        18810
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb301_mod.png 2024-02-28 00:09:00        15148
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb302_mod.png 2024-02-28 00:09:00        12349
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb303_mod.png 2024-02-28 00:09:00        16127
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb304_mod.png 2024-02-28 00:09:00        15808
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb305_mod.png 2024-02-28 00:09:00        17005
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb306_mod.png 2024-02-28 00:09:00        15444
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb307_mod.png 2024-02-28 00:09:00        20904
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb308_mod.png 2024-02-28 00:09:00        20451
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb309_mod.png 2024-02-28 00:09:00        19587
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb310_mod.png 2024-02-28 00:09:00        20172
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb311_mod.png 2024-02-28 00:09:00        20149
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb313_mod.png 2024-02-28 00:09:00        20498
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb316_mod.png 2024-02-28 00:09:00        20305
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb317_mod.png 2024-02-28 00:09:00        12772
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb318_mod.png 2024-02-28 00:09:00        12524
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb319_mod.png 2024-02-28 00:09:00        21519
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb320_mod.png 2024-02-28 00:09:00        21141
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb321_mod.png 2024-02-28 00:09:00        16878
# imagens-tratadas-data/val_set/normais-redimensionadas/mdb322_mod.png 2024-02-28 00:09:00        17207
# Extracting all the files now...
# Done!

# %% [markdown]
# ## 3. Carregamento e pré-processamento das imagens

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    'imagens-tratadas-data/train_set',
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary'
)

validation_generator = validation_datagen.flow_from_directory(
    'imagens-tratadas-data/val_set',
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 286 images belonging to 2 classes.
# Found 44 images belonging to 2 classes.

# %% [markdown]
# # 4. Definição dos modelos

# %% [markdown]
# ### 4.1 Definição CNN do zero:

# %%
print("\n--- Definição da CNN Implementada do Zero (model_cnn_zero) ---")
model_cnn_zero = Sequential([
    Input(shape=(150, 150, 3)),

    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2,2)),
    Dropout(0.25),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
# Out:
# --- Definição da CNN Implementada do Zero (model_cnn_zero) ---

# %%
model_cnn_zero.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model_cnn_zero.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 72, 72, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 34, 34, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 17, 17, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 17, 17, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 36992)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     9,470,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,563,713 (36.48 MB)
#  Trainable params: 9,563,713 (36.48 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 4.2 Definição VGG16 e ResNet152V2 para Transfer Learning

# %%
import keras

model_vgg = keras.applications.VGG16(
    include_top=False,
    weights="imagenet",
    input_shape=(150, 150, 3)
)

model_vgg.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
import keras

model_rsn = keras.applications.ResNet152V2(
    include_top=False,
    weights="imagenet",
    input_shape=(150, 150, 3),
)

model_rsn.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
model = Sequential([
    model_rsn,
    Flatten(),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## 5. Extração de características

# %%
feature_extractor = Sequential([
    model_rsn,
    Flatten()
])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import numpy as np

def extract_features(generator, extractor):
    features = []
    labels = []

    for batch_imgs, batch_labels in generator:
        batch_features = extractor.predict(batch_imgs)
        features.append(batch_features)
        labels.append(batch_labels)

        if len(features) * generator.batch_size >= generator.samples:
            break

    return np.vstack(features), np.hstack(labels)

# %%
X_train, y_train = extract_features(train_generator, feature_extractor)
X_val, y_val = extract_features(validation_generator, feature_extractor)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step

# %% [markdown]
# ## 6. Treinamento dos modelos

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

knn = KNeighborsClassifier(
    n_neighbors=1,
    metric='euclidean',
    weights='uniform'
)

knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=1)

# %%
from sklearn.svm import SVC

svc = SVC(
    kernel='linear',
    probability=True,
    C=0.1,
    gamma='scale'
)
svc.fit(X_train, y_train)
# Out:
# SVC(C=0.1, kernel='linear', probability=True)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42,
    max_depth=10,
    max_features='sqrt',
    min_samples_leaf=2,
    min_samples_split=10
)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=10,
#                        random_state=42)

# %%
history = model.fit(
    train_generator,
    epochs=5,
    validation_data=validation_generator
)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - accuracy: 0.7762 - loss: 0.5486 - val_accuracy: 0.9773 - val_loss: 0.1318
# Epoch 2/5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - accuracy: 0.9720 - loss: 0.0943 - val_accuracy: 0.9773 - val_loss: 0.1925
# Epoch 3/5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9773 - val_loss: 0.2631
# Epoch 4/5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 1.0000 - loss: 4.8437e-04 - val_accuracy: 0.9773 - val_loss: 0.2999
# Epoch 5/5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 1.0000 - loss: 2.4595e-04 - val_accuracy: 0.9773 - val_loss: 0.3151

# %%
print("\n--- Treinamento da CNN Implementada do Zero (model_cnn_zero) ---")
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True
)

history_cnn_zero = model_cnn_zero.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=[early_stopping],
)
# Out:
# --- Treinamento da CNN Implementada do Zero (model_cnn_zero) ---
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.5887 - loss: 1.4984 - val_accuracy: 0.5000 - val_loss: 0.6664
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - accuracy: 0.6761 - loss: 0.5208 - val_accuracy: 0.5000 - val_loss: 0.6457
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.6552 - loss: 0.4915 - val_accuracy: 0.9773 - val_loss: 0.6186
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8183 - loss: 0.3976 - val_accuracy: 0.9773 - val_loss: 0.4075
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.8339 - loss: 0.3655 - val_accuracy: 0.8636 - val_loss: 0.4483
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9180 - loss: 0.2876 - val_accuracy: 0.6591 - val_loss: 0.5913
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9359 - loss: 0.2664 - val_accuracy: 0.9091 - val_loss: 0.4176
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9527 - loss: 0.1531 - val_accuracy: 0.7727 - val_loss: 0.4117
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9783 - loss: 0.0987 - val_accuracy: 0.5000 - val_loss: 0.7475
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.8938 - loss: 0.3160 - val_accuracy: 0.9773 - val_loss: 0.3195
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9636 - loss: 0.1353 - val_accuracy: 0.6818 - val_loss: 0.4877
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9739 - loss: 0.1184 - val_accuracy: 0.9091 - val_loss: 0.3116
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9741 - loss: 0.1425 - val_accuracy: 0.9091 - val_loss: 0.2779

# %% [markdown]
# ## 7. Verificando a acurácia dos modelos

# %%
from scipy.stats import norm

def calculate_confidence_interval(accuracy, n_samples, confidence_level=0.95):
    """Calcula o Intervalo de Confiança de 95% (Aproximação Normal)"""
    if n_samples == 0:
        return (0.0, 0.0)

    z_score = norm.ppf(1 - (1 - confidence_level) / 2)

    standard_error = np.sqrt((accuracy * (1 - accuracy)) / n_samples)

    margin_of_error = z_score * standard_error

    lower_bound = accuracy - margin_of_error
    upper_bound = accuracy + margin_of_error

    lower_bound = max(0.0, lower_bound)
    upper_bound = min(1.0, upper_bound)

    return (lower_bound, upper_bound)

N_val = len(y_val)


print("\n--- Intervalos de Confiança (IC) de 95% para Modelos Clássicos ---")

knn_accuracy = accuracy_score(y_val, knn.predict(X_val))
knn_ci_lower, knn_ci_upper = calculate_confidence_interval(knn_accuracy, N_val)
print(f"KNN Accuracy: {knn_accuracy:.4f} (IC 95%: [{knn_ci_lower:.4f}, {knn_ci_upper:.4f}])")

svc_accuracy = accuracy_score(y_val, svc.predict(X_val))
svc_ci_lower, svc_ci_upper = calculate_confidence_interval(svc_accuracy, N_val)
print(f"SVC Accuracy: {svc_accuracy:.4f} (IC 95%: [{svc_ci_lower:.4f}, {svc_ci_upper:.4f}])")

rf_accuracy = accuracy_score(y_val, rf.predict(X_val))
rf_ci_lower, rf_ci_upper = calculate_confidence_interval(rf_accuracy, N_val)
print(f"Random Forest Accuracy: {rf_accuracy:.4f} (IC 95%: [{rf_ci_lower:.4f}, {rf_ci_upper:.4f}])")

_, nn_accuracy = model.evaluate(validation_generator, verbose=0)
nn_ci_lower, nn_ci_upper = calculate_confidence_interval(nn_accuracy, validation_generator.samples) # Usa validation_generator.samples
print(f"ResNet (TL) Accuracy: {nn_accuracy:.4f} (IC 95%: [{nn_ci_lower:.4f}, {nn_ci_upper:.4f}])")

_, cnn_zero_accuracy = model_cnn_zero.evaluate(validation_generator, verbose=0)
cnn_zero_ci_lower, cnn_zero_ci_upper = calculate_confidence_interval(cnn_zero_accuracy, validation_generator.samples)
print(f"CNN do Zero Accuracy: {cnn_zero_accuracy:.4f} (IC 95%: [{cnn_zero_ci_lower:.4f}, {cnn_zero_ci_upper:.4f}])")
# Out:
# --- Intervalos de Confiança (IC) de 95% para Modelos Clássicos ---
# KNN Accuracy: 0.9773 (IC 95%: [0.9332, 1.0000])
# SVC Accuracy: 0.9773 (IC 95%: [0.9332, 1.0000])
# Random Forest Accuracy: 0.9773 (IC 95%: [0.9332, 1.0000])
# ResNet (TL) Accuracy: 0.9773 (IC 95%: [0.9332, 1.0000])
# CNN do Zero Accuracy: 0.9773 (IC 95%: [0.9332, 1.0000])

# %%
y_pred = knn.predict(X_val)

print("KNN Accuracy:", accuracy_score(y_val, y_pred))
print(classification_report(y_val, y_pred))
# Out:
# KNN Accuracy: 0.9772727272727273
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.95      0.98        22
#          1.0       0.96      1.00      0.98        22
#
#     accuracy                           0.98        44
#    macro avg       0.98      0.98      0.98        44
# weighted avg       0.98      0.98      0.98        44

# %%
y_pred = svc.predict(X_val)

print("SVC Accuracy:", accuracy_score(y_val, y_pred))
print(classification_report(y_val, y_pred))
# Out:
# SVC Accuracy: 0.9772727272727273
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.95      0.98        22
#          1.0       0.96      1.00      0.98        22
#
#     accuracy                           0.98        44
#    macro avg       0.98      0.98      0.98        44
# weighted avg       0.98      0.98      0.98        44

# %%
y_pred = rf.predict(X_val)

print("Random Forest Accuracy:", accuracy_score(y_val, y_pred))
print(classification_report(y_val, y_pred))
# Out:
# Random Forest Accuracy: 0.9772727272727273
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.95      0.98        22
#          1.0       0.96      1.00      0.98        22
#
#     accuracy                           0.98        44
#    macro avg       0.98      0.98      0.98        44
# weighted avg       0.98      0.98      0.98        44

# %%
loss, accuracy = model.evaluate(validation_generator)
print("Accuracy: ", accuracy)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9848 - loss: 0.2104
# Accuracy:  0.9772727489471436

# %%
print("\n--- Avaliação da CNN Implementada do Zero (model_cnn_zero) ---")
loss_cnn_zero, accuracy_cnn_zero = model_cnn_zero.evaluate(validation_generator)
print("CNN do Zero Accuracy: ", accuracy_cnn_zero)
# Out:
# --- Avaliação da CNN Implementada do Zero (model_cnn_zero) ---
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9744 - loss: 0.6185
# CNN do Zero Accuracy:  0.9772727489471436

# %% [markdown]
# ## 8. Realizar predições e visualizar-las

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import numpy as np

cor_clara = '#FFB6C1'
cor_escura = '#FF69B4'
cor_texto = '#333333'

loss, nn_accuracy = model.evaluate(validation_generator, verbose=0)
loss_cnn_zero, cnn_zero_accuracy = model_cnn_zero.evaluate(validation_generator, verbose=0)

y_pred_rf = rf.predict(X_val)
rf_accuracy = accuracy_score(y_val, y_pred_rf)

y_pred_svc = svc.predict(X_val)
svc_accuracy = accuracy_score(y_val, y_pred_svc)

y_pred_knn = knn.predict(X_val)
knn_accuracy = accuracy_score(y_val, y_pred_knn)

print("\nAcurácia dos modelos:")
print("---------------------")
print(f"Transfer Learning (ResNet): {nn_accuracy:.10f}")
print(f"CNN do Zero:               {cnn_zero_accuracy:.10f}")
print(f"Random Forest:             {rf_accuracy:.10f}")
print(f"SVC:                       {svc_accuracy:.10f}")
print(f"KNN:                       {knn_accuracy:.10f}\n")

modelos = ['Transfer Learning', 'CNN do Zero', 'Random Forest', 'SVM', 'KNN']
acuracia_abs = [nn_accuracy, cnn_zero_accuracy, rf_accuracy, svc_accuracy, knn_accuracy]
acuracia = [acc * 100 for acc in acuracia_abs]

plt.figure(figsize=(10, 5))
barras = plt.bar(modelos, acuracia, color=cor_clara, width=0.7)

plt.ylim(0, 100)
plt.ylabel('Acurácia (%)', color=cor_texto)
plt.title('Comparação de Desempenho (Vista Geral)', pad=15, color=cor_texto)

for barra in barras:
    altura = barra.get_height()
    plt.text(
        barra.get_x() + barra.get_width() / 2,
        altura + 2,
        f'{altura:.1f}%',
        ha='center',
        va='bottom',
        color=cor_texto
    )

plt.gca().spines[['top', 'right']].set_visible(False)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 5))

min_acuracia = min(acuracia)
diferencas = [acc - min_acuracia for acc in acuracia]
diferencas_micro = [diff * 1e6 for diff in diferencas]

barras_diff = plt.bar(modelos, diferencas_micro, color=cor_escura, width=0.7)

plt.ylim(0, max(diferencas_micro) * 1.2)
plt.ylabel('Diferença (× 0.000001%)', color=cor_texto)
plt.title('Diferenças Ampliadas (em Micro Porcentagens)', pad=15, color=cor_texto)

for barra in barras_diff:
    altura = barra.get_height()
    if altura > 0:
        plt.text(
            barra.get_x() + barra.get_width() / 2,
            altura,
            f'+{altura:.2f}',
            ha='center',
            va='bottom',
            color='black'
        )
    else:
        plt.text(
            barra.get_x() + barra.get_width() / 2,
            0,
            f'{altura:.2f}',
            ha='center',
            va='bottom',
            color='black'
        )

plt.gca().spines[['top', 'right']].set_visible(False)
plt.tight_layout()
plt.show()
# Out:
# Acurácia dos modelos:
# ---------------------
# Transfer Learning (ResNet): 0.9772727489
# CNN do Zero:               0.9772727489
# Random Forest:             0.9772727273
# SVC:                       0.9772727273
# KNN:                       0.9772727273
